# %% [markdown]
# <a href="https://colab.research.google.com/github/Repezel/ML-model-1/blob/main/model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://raw.githubusercontent.com/rupakc/UCI-Data-Analysis/master/Boston%20Housing%20Dataset/Boston%20Housing/housing.data
# !wget https://raw.githubusercontent.com/rupakc/UCI-Data-Analysis/master/Boston%20Housing%20Dataset/Boston%20Housing/housing.names
# Out:
# --2026-02-15 08:10:59--  https://raw.githubusercontent.com/rupakc/UCI-Data-Analysis/master/Boston%20Housing%20Dataset/Boston%20Housing/housing.data
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49082 (48K) [text/plain]
# Saving to: ‘housing.data’
#
# housing.data        100%[===================>]  47.93K  --.-KB/s    in 0.002s
#
# 2026-02-15 08:10:59 (23.0 MB/s) - ‘housing.data’ saved [49082/49082]
#
# --2026-02-15 08:10:59--  https://raw.githubusercontent.com/rupakc/UCI-Data-Analysis/master/Boston%20Housing%20Dataset/Boston%20Housing/housing.names
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# ...

# %%
# !ls
# Out:
# housing.data  housing.names  sample_data

# %%
# !ls
# Out:
# housing.data  housing.names  sample_data

# %%
# !mkdir -p data

# %%
# !mv housing.data housing.names data/

# %%
# !ls data
# Out:
# housing.data  housing.names

# %%
# !git add data/
# !git commit -m "Add Boston Housing dataset"
# !git push origin main
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
# %cd ML-model-1
# !ls
# Out:
# [Errno 2] No such file or directory: 'ML-model-1'
# /content
# data  sample_data

# %%
# !git clone https://github.com/Repezel/ML-model-1.git
# Out:
# Cloning into 'ML-model-1'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), done.

# %%
# %cd ML-model-1
# !ls
# Out:
# /content/ML-model-1
# model.ipynb  README.md

# %%
# !mkdir -p data
# !cp ../data/housing.data ../data/housing.names data/

# %%
# !ls data
# Out:
# housing.data  housing.names

# %%
# !git add data/
# !git commit -m "Add Boston Housing dataset"
# !git push origin main
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@1ba7cfeb026f.(none)')
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git config --global user.name "Repezel"
# !git config --global user.email "zepsapam@gmail.com"

# %%
# !git push origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3868686679.py in <cell line: 0>()
# ----> 1 Repezel
#
# NameError: name 'Repezel' is not defined

# %%
# !git push origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address
